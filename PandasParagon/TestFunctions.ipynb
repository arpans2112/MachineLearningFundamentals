# %%
import pandas as pd

# %% [markdown]
# #### click three dots given below to unhide the cell

# %%
students = [
    {"id": 1, "name": "Alice Johnson", "age": 20, "gpa": 3.5, "is_enrolled": True, "courses": ["Math", "Science"]},
    {"id": 2, "name": "Bob Smith", "age": 21, "gpa": 3.7, "is_enrolled": False, "courses": ["History", "Math"]},
    {"id": 3, "name": "Charlie Brown", "age": 22, "gpa": 2.9, "is_enrolled": True, "courses": ["Science", "Art"]},
    {"id": 4, "name": "David Wilson", "age": 19, "gpa": 3.2, "is_enrolled": True, "courses": ["English", "History"]},
    {"id": 5, "name": "Eva Green", "age": 20, "gpa": 3.8, "is_enrolled": False, "courses": ["Math", "Art"]},
    {"id": 6, "name": "Frank Black", "age": 21, "gpa": 2.5, "is_enrolled": True, "courses": ["Science", "English"]},
    {"id": 7, "name": "Grace White", "age": 22, "gpa": 3.1, "is_enrolled": False, "courses": ["History", "Science"]},
    {"id": 8, "name": "Hannah Blue", "age": 19, "gpa": 3.6, "is_enrolled": True, "courses": ["Art", "Math"]},
    {"id": 9, "name": "Ian Gray", "age": 20, "gpa": 2.7, "is_enrolled": True, "courses": ["Math", "English"]},
    {"id": 10, "name": "Jane Black", "age": 21, "gpa": 3.4, "is_enrolled": False, "courses": ["Science", "History"]},
    {"id": 11, "name": "Kyle Brown", "age": 22, "gpa": 2.8, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 12, "name": "Laura Smith", "age": 19, "gpa": 3.9, "is_enrolled": True, "courses": ["English", "Math"]},
    {"id": 13, "name": "Mike Johnson", "age": 20, "gpa": 2.6, "is_enrolled": False, "courses": ["Science", "History"]},
    {"id": 14, "name": "Nina Wilson", "age": 21, "gpa": 3.3, "is_enrolled": True, "courses": ["Art", "English"]},
    {"id": 15, "name": "Oscar Green", "age": 22, "gpa": 3.5, "is_enrolled": False, "courses": ["Math", "Science"]},
    {"id": 16, "name": "Paul Black", "age": 19, "gpa": 3.0, "is_enrolled": True, "courses": ["History", "Math"]},
    {"id": 17, "name": "Quinn White", "age": 20, "gpa": 2.9, "is_enrolled": True, "courses": ["Science", "Art"]},
    {"id": 18, "name": "Rachel Blue", "age": 21, "gpa": 3.7, "is_enrolled": False, "courses": ["English", "History"]},
    {"id": 19, "name": "Sam Gray", "age": 22, "gpa": 2.5, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 20, "name": "Tina Black", "age": 19, "gpa": 3.2, "is_enrolled": True, "courses": ["Science", "English"]},
    {"id": 21, "name": "Uma Brown", "age": 20, "gpa": 3.6, "is_enrolled": False, "courses": ["History", "Science"]},
    {"id": 22, "name": "Vince Smith", "age": 21, "gpa": 2.8, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 23, "name": "Wendy Johnson", "age": 22, "gpa": 3.4, "is_enrolled": False, "courses": ["Science", "Math"]},
    {"id": 24, "name": "Xander Wilson", "age": 19, "gpa": 2.7, "is_enrolled": True, "courses": ["English", "History"]},
    {"id": 25, "name": "Yara Green", "age": 20, "gpa": 3.5, "is_enrolled": True, "courses": ["Art", "Science"]},
    {"id": 26, "name": "Zack Black", "age": 21, "gpa": 2.6, "is_enrolled": False, "courses": ["Math", "English"]},
    {"id": 27, "name": "Amy White", "age": 22, "gpa": 3.3, "is_enrolled": True, "courses": ["History", "Science"]},
    {"id": 28, "name": "Bill Blue", "age": 19, "gpa": 3.1, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 29, "name": "Cathy Gray", "age": 20, "gpa": 2.9, "is_enrolled": False, "courses": ["Science", "English"]},
    {"id": 30, "name": "Dan Black", "age": 21, "gpa": 3.7, "is_enrolled": True, "courses": ["History", "Math"]},
    {"id": 31, "name": "Eve Brown", "age": 22, "gpa": 2.5, "is_enrolled": True, "courses": ["Art", "Science"]},
    {"id": 32, "name": "Finn Smith", "age": 19, "gpa": 3.0, "is_enrolled": False, "courses": ["English", "History"]},
    {"id": 33, "name": "Gina Johnson", "age": 20, "gpa": 3.8, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 34, "name": "Hugo Wilson", "age": 21, "gpa": 2.6, "is_enrolled": True, "courses": ["Science", "English"]},
    {"id": 35, "name": "Ivy Green", "age": 22, "gpa": 3.5, "is_enrolled": False, "courses": ["History", "Math"]},
    {"id": 36, "name": "Jake Black", "age": 19, "gpa": 2.8, "is_enrolled": True, "courses": ["Art", "Science"]},
    {"id": 37, "name": "Kim Brown", "age": 20, "gpa": 3.4, "is_enrolled": False, "courses": ["English", "History"]},
    {"id": 38, "name": "Liam Smith", "age": 21, "gpa": 2.7, "is_enrolled": True, "courses": ["Math", "Art"]},
    {"id": 39, "name": "Mia Johnson", "age": 22, "gpa": 3.6, "is_enrolled": True, "courses": ["Science", "Math"]},
    {"id": 40, "name": "Nate Wilson", "age": 19, "gpa": 3.2, "is_enrolled": False, "courses": ["History", "English"]}
]

# %% [markdown]
# ### create dataframe

# %%
student_df = pd.DataFrame(students)

# %%
student_df.head()
# Out:
#    id           name  age  gpa  is_enrolled             courses
# 0   1  Alice Johnson   20  3.5         True     [Math, Science]
# 1   2      Bob Smith   21  3.7        False     [History, Math]
# 2   3  Charlie Brown   22  2.9         True      [Science, Art]
# 3   4   David Wilson   19  3.2         True  [English, History]
# 4   5      Eva Green   20  3.8        False         [Math, Art]

# %%
student_df.tail()
# Out:
#     id         name  age  gpa  is_enrolled             courses
# 35  36   Jake Black   19  2.8         True      [Art, Science]
# 36  37    Kim Brown   20  3.4        False  [English, History]
# 37  38   Liam Smith   21  2.7         True         [Math, Art]
# 38  39  Mia Johnson   22  3.6         True     [Science, Math]
# 39  40  Nate Wilson   19  3.2        False  [History, English]

# %%
student_df.describe()
# Out:
#               id        age        gpa
# count  40.000000  40.000000  40.000000
# mean   20.500000  20.500000   3.162500
# std    11.690452   1.132277   0.424679
# min     1.000000  19.000000   2.500000
# 25%    10.750000  19.750000   2.800000
# 50%    20.500000  20.500000   3.200000
# 75%    30.250000  21.250000   3.500000
# max    40.000000  22.000000   3.900000

# %%
student_df.describe(include='all')
# Out:
#                id           name        age        gpa is_enrolled  \
# count   40.000000             40  40.000000  40.000000          40
# unique        NaN             40        NaN        NaN           2
# top           NaN  Alice Johnson        NaN        NaN        True
# freq          NaN              1        NaN        NaN          25
# mean    20.500000            NaN  20.500000   3.162500         NaN
# std     11.690452            NaN   1.132277   0.424679         NaN
# min      1.000000            NaN  19.000000   2.500000         NaN
# 25%     10.750000            NaN  19.750000   2.800000         NaN
# 50%     20.500000            NaN  20.500000   3.200000         NaN
# 75%     30.250000            NaN  21.250000   3.500000         NaN
# max     40.000000            NaN  22.000000   3.900000         NaN
#
#             courses
# count            40
# unique           15
# top     [Math, Art]
# freq              7
# mean            NaN
# std             NaN
# ...

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           40 non-null     int64
#  1   name         40 non-null     object
#  2   age          40 non-null     int64
#  3   gpa          40 non-null     float64
#  4   is_enrolled  40 non-null     bool
#  5   courses      40 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(2)
# memory usage: 1.7+ KB

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_xlim(0, 12)
ax.set_ylim(0, 8)
ax.axis('off')

# Define positions and labels for the techniques
techniques = [
    {"label": "Removing Duplicates", "code": "df.drop_duplicates()", "icon": "duplicate.png", "pos": (1, 6)},
    {"label": "Handling Missing Values", "code": "df.fillna(value)\ndf.dropna()", "icon": "missing.png", "pos": (4, 6)},
    {"label": "Data Transformation", "code": "df['column'].apply(func)", "icon": "transform.png", "pos": (7, 6)},
    {"label": "Standardization and Normalization", "code": "StandardScaler()\nMinMaxScaler()", "icon": "standardize.png", "pos": (10, 6)},
    {"label": "Feature Engineering", "code": "pd.get_dummies(df['category'])", "icon": "feature.png", "pos": (1, 3)},
    {"label": "Handling Outliers", "code": "df[df['column'] < threshold]", "icon": "outlier.png", "pos": (4, 3)},
    {"label": "Data Integration", "code": "pd.merge(df1, df2, on='key')", "icon": "integration.png", "pos": (7, 3)},
    {"label": "Data Aggregation", "code": "df.groupby('column').sum()", "icon": "aggregation.png", "pos": (10, 3)}
]

# Draw central box
ax.text(6, 7.5, "Data Cleaning and Wrangling in Python", ha='center', va='center', fontsize=14, fontweight='bold', bbox=dict(facecolor='lightgrey', edgecolor='black'))

# Draw technique boxes
for tech in techniques:
    x, y = tech["pos"]
    ax.text(x, y, f"{tech['label']}\n\n{tech['code']}", ha='center', va='center', fontsize=10, bbox=dict(facecolor='lightblue', edgecolor='black'))
    # Note: Add icon drawing code here if you have icons

plt.show()

# %%
# !pip install pyodide-py
